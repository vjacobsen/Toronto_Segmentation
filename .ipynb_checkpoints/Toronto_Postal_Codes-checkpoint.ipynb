# %% [markdown]
# # Part 1

# %%
import pandas as pd
import numpy as np

# %%
# Original table from Wikipedia
wiki_table = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
wiki_table.head()
# Out:
#                                                    0                1  \
# 0                                    M1ANot assigned  M2ANot assigned
# 1                    M1BScarborough(Malvern / Rouge)  M2BNot assigned
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...  M2CNot assigned
# 3  M1EScarborough(Guildwood / Morningside / West ...  M2ENot assigned
# 4                             M1GScarborough(Woburn)  M2GNot assigned
#
#                                                 2  \
# 0                        M3ANorth York(Parkwoods)
# 1                   M3BNorth York(Don Mills)North
# 2  M3CNorth York(Don Mills)South(Flemingdon Park)
# 3                                 M3ENot assigned
# 4                                 M3GNot assigned
#
#                                                 3  \
# 0                 M4ANorth York(Victoria Village)
# 1  M4BEast York(Parkview Hill / Woodbine Gardens)
# 2                  M4CEast York(Woodbine Heights)
# 3                    M4EEast Toronto(The Beaches)
# 4                           M4GEast York(Leaside)
#
#                                                  4  \
# 0  M5ADowntown Toronto(Regent Park / Harbourfront)
# 1    M5BDowntown Toronto(Garden District, Ryerson)
# 2              M5CDowntown Toronto(St. James Town)
# 3                 M5EDowntown Toronto(Berczy Park)
# 4          M5GDowntown Toronto(Central Bay Street)
#
#                                                   5  \
# 0  M6ANorth York(Lawrence Manor / Lawrence Heights)
# 1                          M6BNorth York(Glencairn)
# 2                       M6CYork(Humewood-Cedarvale)
# 3                      M6EYork(Caledonia-Fairbanks)
# 4                     M6GDowntown Toronto(Christie)
#
#                                                    6                7  \
# 0  M7ADowntown Toronto(Queen's Park / Ontario Pro...  M8ANot assigned
# 1                                    M7BNot assigned  M8BNot assigned
# 2                                    M7CNot assigned  M8CNot assigned
# 3                                    M7ENot assigned  M8ENot assigned
# 4                                    M7GNot assigned  M8GNot assigned
#
#                                                    8
# 0                     M9AEtobicoke(Islington Avenue)
# 1  M9BEtobicoke(West Deane Park / Princess Garden...
# 2  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                    M9ENot assigned
# 4                                    M9GNot assigned

# %%
# Convert from wide to long format
melted_table = pd.melt(wiki_table)[['value']]
melted_table.head()
# Out:
#                                                value
# 0                                    M1ANot assigned
# 1                    M1BScarborough(Malvern / Rouge)
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...
# 3  M1EScarborough(Guildwood / Morningside / West ...
# 4                             M1GScarborough(Woburn)

# %% [markdown]
# ## Formatting

# %%
# Extract postal code
df['PostalCode'] = melted_table['value'].str[:3]
df.sample(10)
# Out:
#                                                  value PostalCode  \
# 106         M6JWest Toronto(Little Portugal / Trinity)        M6J
# 17                         M1XScarborough(Upper Rouge)        M1X
# 88   M5LDowntown Toronto(Commerce Court / Victoria ...        M5L
# 5                            M1HScarborough(Cedarbrae)        M1H
# 172  M9REtobicoke(Kingsview Village / St. Phillips ...        M9R
# 103                       M6EYork(Caledonia-Fairbanks)        M6E
# 26       M2JNorth York(Fairview / Henry Farm / Oriole)        M2J
# 168                       M9LNorth York(Humber Summit)        M9L
# 161  M9BEtobicoke(West Deane Park / Princess Garden...        M9B
# 63                        M4EEast Toronto(The Beaches)        M4E
#
#               Borough                                       Neighborhood
# 106      West Toronto                           Little Portugal, Trinity
# 17        Scarborough                                        Upper Rouge
# 88   Downtown Toronto                     Commerce Court, Victoria Hotel
# 5         Scarborough                                          Cedarbrae
# 172         Etobicoke  Kingsview Village, St. Phillips, Martin Grove ...
# 103              York                                Caledonia-Fairbanks
# 26         North York                       Fairview, Henry Farm, Oriole
# 168        North York                                      Humber Summit
# 161         Etobicoke  West Deane Park, Princess Gardens, Martin Grov...
# 63       East Toronto                                        The Beaches

# %%
# Extract Borough
df['Borough'] = df['value'].str.slice(3)

# Split Borough at '(', resulting in two columns since we use expand=True
df[['Borough','Neighborhood']] = df['Borough'].str.split(pat="(",n=1,expand=True)
df.head()
# Out:
# /Users/victor/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                value PostalCode      Borough  \
# 1                    M1BScarborough(Malvern / Rouge)        M1B  Scarborough
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...        M1C  Scarborough
# 3  M1EScarborough(Guildwood / Morningside / West ...        M1E  Scarborough
# 4                             M1GScarborough(Woburn)        M1G  Scarborough
# 5                          M1HScarborough(Cedarbrae)        M1H  Scarborough
#
#                                 Neighborhood
# 1                           Malvern / Rouge)
# 2  Rouge Hill / Port Union / Highland Creek)
# 3       Guildwood / Morningside / West Hill)
# 4                                    Woburn)
# 5                                 Cedarbrae)

# %%
# drop value colum
df = df.drop(columns='value')
df.head()
# Out:
#   PostalCode      Borough                               Neighborhood
# 1        M1B  Scarborough                           Malvern / Rouge)
# 2        M1C  Scarborough  Rouge Hill / Port Union / Highland Creek)
# 3        M1E  Scarborough       Guildwood / Morningside / West Hill)
# 4        M1G  Scarborough                                    Woburn)
# 5        M1H  Scarborough                                 Cedarbrae)

# %%
# Separate neighborhoods with a comma instead of slash
df['Neighborhood'] = df['Neighborhood'].str.replace(')','')
df['Neighborhood'] = df['Neighborhood'].str.replace(' / ',', ')
df.head()
# Out:
# /Users/victor/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/victor/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                value PostalCode      Borough  \
# 1                    M1BScarborough(Malvern / Rouge)        M1B  Scarborough
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...        M1C  Scarborough
# 3  M1EScarborough(Guildwood / Morningside / West ...        M1E  Scarborough
# 4                             M1GScarborough(Woburn)        M1G  Scarborough
# 5                          M1HScarborough(Cedarbrae)        M1H  Scarborough
#
#                              Neighborhood
# 1                          Malvern, Rouge
# 2  Rouge Hill, Port Union, Highland Creek
# 3       Guildwood, Morningside, West Hill
# 4                                  Woburn
# 5                               Cedarbrae

# %%
# Need to convert neighborhoods from wide to long format
df = df.drop(columns=['Neighborhood'])
df = df.melt(id_vars=['PostalCode','Borough'],value_name='Neighborhood').drop(columns=['variable'])
df.sample(10)

# %%
# Finally, we drop rows where neighborhood is None
df = df.dropna()
df.sample(10)
# Out:
#     PostalCode                Borough                    Neighborhood
# 163        M5K       Downtown Toronto                 Design Exchange
# 195        M8Z              Etobicoke             The Queensway West
# 40         M4J  East YorkEast Toronto               The Danforth East
# 188        M7A       Downtown Toronto   Ontario Provincial Government
# 2          M1E            Scarborough                      Guildwood
# 194        M8Y              Etobicoke               King's Mill Park
# 13         M1T            Scarborough                 Clarks Corners
# 180        M6J           West Toronto                         Trinity
# 154        M4X       Downtown Toronto                     Cabbagetown
# 88         M8V              Etobicoke                    New Toronto
